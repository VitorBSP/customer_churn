# %% [markdown]
# # Objetivo

# %% [markdown]
# ## Reduzir churn

# %% [markdown]
# A empresa de telecomunicações contratou a A3Data para avaliar o cenário de
# churn elevado dos seus clientes e, uma vez que estamos falando de um produto
# com custo elevado de setup (instalação), a empresa gostaria de uma estratégia
# para reduzir esse churn.

# %% [markdown]
# # Imports iniciais

# %%
import pandas as pd
import numpy as np
from typing import Dict, Any, List


from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import (
    classification_report,
    roc_auc_score,
    confusion_matrix,
)

# %%
churn = pd.read_csv("data/customer_churn_verified.csv")

# %%
churn.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7569-NMZYQ  Female              0     Yes        Yes      72          Yes
# 1  8984-HPEMB  Female              0      No         No      71          Yes
# 2  5989-AXPUC  Female              0     Yes         No      68          Yes
# 3  5734-EJKXG  Female              0      No         No      61          Yes
# 4  8199-ZLLSA    Male              0      No         No      67          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... PaperlessBilling  \
# 0           Yes     Fiber optic            Yes  ...              Yes
# 1           Yes     Fiber optic            Yes  ...              Yes
# 2           Yes     Fiber optic            Yes  ...               No
# 3           Yes     Fiber optic            Yes  ...              Yes
# 4           Yes     Fiber optic            Yes  ...              Yes
#
#                PaymentMethod MonthlyCharges TotalCharges Churn tenure_bucket  \
# 0  Bank transfer (automatic)         118.75      8672.45    No          61m+
# 1           Electronic check         118.65      8477.60    No          61m+
# 2               Mailed check         118.60      7990.05    No          61m+
# 3           Electronic check         118.60      7365.70    No          61m+
# 4  Bank transfer (automatic)         118.35      7804.15   Yes          61m+
#
#   charge_quantile addon_count  ChurnFlag  high_value_customer
# 0              Q4           6          0                    1
# 1              Q4           6          0                    1
# 2              Q4           6          0                    1
# 3              Q4           6          0                    1
# 4              Q4           6          1                    1
#
# [5 rows x 26 columns]

# %% [markdown]
# # Preparação

# %%
num_cols = ["tenure", "MonthlyCharges", "TotalCharges", "addon_count"]
cat_cols = [
    c
    for c in churn.columns
    if c not in num_cols + ["customerID", "Churn", "ChurnFlag"]
    and churn[c].dtype == "object"
]

# %%
churn["ChurnFlag"] = churn["Churn"].map({"No": 0, "Yes": 1})

# %%
cat_cols += ["SeniorCitizen", "high_value_customer"]

# %%
X = churn[num_cols + cat_cols]
y = churn["ChurnFlag"]

# %%
random_number = 42

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, stratify=y, random_state=random_number
)

# %%
numeric_pipe = Pipeline(
    [
        ("impute", SimpleImputer(strategy="median")),
        ("scale", StandardScaler()),
    ]
)
categorical_pipe = Pipeline(
    [
        ("impute", SimpleImputer(strategy="most_frequent")),
        ("encode", OneHotEncoder(handle_unknown="ignore")),
    ]
)

preprocess = ColumnTransformer(
    [
        ("num", numeric_pipe, num_cols),
        ("cat", categorical_pipe, cat_cols),
    ]
)

# %% [markdown]
# # Modelagem

# %%
def train_eval(
    name: str,
    estimator,
    *,
    preprocess: ColumnTransformer,
    X_train: pd.DataFrame,
    X_test: pd.DataFrame,
    y_train: pd.Series,
    y_test: pd.Series,
    num_cols: List[str],
    cat_cols: List[str],
) -> Dict[str, Any]:
    """
    Treina <estimator> dentro de um Pipeline, avalia no hold-out
    e retorna métricas + importância de variáveis (quando disponível).

    Parameters
    ----------
    name : str
        Rótulo para o modelo (ex.: 'RandomForest').
    estimator : scikit-learn estimator
        Algoritmo de classificação já instanciado.
    preprocess : ColumnTransformer
        Transformações numéricas/categóricas.
    X_train, X_test, y_train, y_test
        Conjuntos de dados estratificados.
    num_cols, cat_cols : list[str]
        Listas originais de colunas numéricas e categóricas.

    Returns
    -------
    dict
        Contém métricas, previsões, nomes de features expandidas
        e DataFrame `importance_df` ordenado (ou None).
    """

    pipe = Pipeline([("prep", preprocess), ("clf", estimator)])
    pipe.fit(X_train, y_train)
    pred = pipe.predict(X_test)
    proba = pipe.predict_proba(X_test)[:, 1]

    auc = roc_auc_score(y_test, proba)
    cm = confusion_matrix(y_test, pred)
    report = classification_report(y_test, pred, digits=3, output_dict=True)

    # Recuperando nome das variáveis
    numeric_feats = num_cols

    encoder = (pipe.named_steps["prep"].named_transformers_["cat"]
               .named_steps["encode"])
    cat_feats = encoder.get_feature_names_out(cat_cols).tolist()

    feature_names = numeric_feats + cat_feats

    clf = pipe.named_steps["clf"]
    importances = None

    if hasattr(clf, "feature_importances_"):
        importances = clf.feature_importances_

    # Modelos lineares (LogisticRegression)
    elif hasattr(clf, "coef_"):
        importances = np.abs(clf.coef_).ravel()

    if importances is not None:
        importance_df = (
            pd.DataFrame({"feature": feature_names, "importance": importances})
            .sort_values("importance", ascending=False)
            .reset_index(drop=True)
        )
    else:
        importance_df = None  # Ex.: KNN não possui importâncias

    return {
        "name": name,
        "model": pipe,
        "auc": auc,
        "cm": cm,
        "report": report,
        "feature_names": feature_names,
        "importances": importances,
        "importance_df": importance_df,
        "pred": pred,
        "proba": proba,
    }

# %%
models_info = []

# %%
models_info.append(
    train_eval(
        "LogReg",
        LogisticRegression(max_iter=3000, class_weight="balanced", 
                           solver="liblinear"),
        preprocess=preprocess,
        X_train=X_train,
        X_test=X_test,
        y_train=y_train,
        y_test=y_test,
        num_cols=num_cols,
        cat_cols=cat_cols,
    )
)

# %%
models_info[0]["importance_df"]
# Out:
#                                     feature  importance
# 0                         tenure_bucket_≤6m    0.932911
# 1                         Contract_Two year    0.827167
# 2                   Contract_Month-to-month    0.732737
# 3                        tenure_bucket_61m+    0.687112
# 4                                    tenure    0.543585
# 5               InternetService_Fiber optic    0.539928
# 6                       InternetService_DSL    0.488058
# 7                            MonthlyCharges    0.425754
# 8                        charge_quantile_Q1    0.272953
# 9                      tenure_bucket_49-60m    0.258452
# 10                     tenure_bucket_25-48m    0.246739
# 11                             TotalCharges    0.240849
# 12                      PaperlessBilling_No    0.239913
# 13                        OnlineSecurity_No    0.220679
# 14           PaymentMethod_Electronic check    0.218200
# 15                      tenure_bucket_7-12m    0.205148
# 16                          SeniorCitizen_0    0.203000
# 17                         MultipleLines_No    0.197939
# 18                       charge_quantile_Q4    0.191003
# 19       OnlineSecurity_No internet service    0.186068
# 20          TechSupport_No internet service    0.186068
# 21          StreamingTV_No internet service    0.186068
# 22      StreamingMovies_No internet service    0.186068
# 23     DeviceProtection_No internet service    0.186068
# 24         OnlineBackup_No internet service    0.186068
# 25                       InternetService_No    0.186068
# 26               PaymentMethod_Mailed check    0.180039
# 27                       OnlineSecurity_Yes    0.168810
# 28                          StreamingTV_Yes    0.150122
# 29                    high_value_customer_0    0.147083
# 30                           TechSupport_No    0.141268
# 31                              addon_count    0.141266
# 32                           Dependents_Yes    0.140537
# 33                      StreamingMovies_Yes    0.134247
# 34                         PhoneService_Yes    0.130447
# 35    PaymentMethod_Credit card (automatic)    0.114835
# 36                     PaperlessBilling_Yes    0.105715
# 37                          OnlineBackup_No    0.101813
# 38                           StreamingTV_No    0.098252
# 39                          TechSupport_Yes    0.089399
# 40                              gender_Male    0.089091
# 41                               Partner_No    0.085288
# 42                       StreamingMovies_No    0.082377
# 43                     tenure_bucket_13-24m    0.079954
# 44                       charge_quantile_Q2    0.072033
# 45                          SeniorCitizen_1    0.068802
# 46                        MultipleLines_Yes    0.067492
# 47  PaymentMethod_Bank transfer (automatic)    0.057524
# 48                         OnlineBackup_Yes    0.049943
# 49                              Partner_Yes    0.048910
# 50                            gender_Female    0.045107
# 51                        Contract_One year    0.039768
# 52                      DeviceProtection_No    0.039719
# 53                       charge_quantile_Q3    0.019785
# 54                    high_value_customer_1    0.012885
# 55                     DeviceProtection_Yes    0.012150
# 56                            Dependents_No    0.006339
# 57           MultipleLines_No phone service    0.003751
# 58                          PhoneService_No    0.003751

# %%
models_info.append(
    train_eval(
        "RandomForest",
        RandomForestClassifier(
            n_estimators=1000,
            random_state=42,
        ),
        preprocess=preprocess,
        X_train=X_train,
        X_test=X_test,
        y_train=y_train,
        y_test=y_test,
        num_cols=num_cols,
        cat_cols=cat_cols,
    )
)

# %%
models_info[1]["importance_df"]
# Out:
#                                     feature  importance
# 0                              TotalCharges    0.133855
# 1                            MonthlyCharges    0.117079
# 2                                    tenure    0.110197
# 3                   Contract_Month-to-month    0.046068
# 4                               addon_count    0.027460
# 5            PaymentMethod_Electronic check    0.027411
# 6                         OnlineSecurity_No    0.026989
# 7                         tenure_bucket_≤6m    0.026306
# 8                            TechSupport_No    0.023605
# 9               InternetService_Fiber optic    0.021682
# 10                              gender_Male    0.017889
# 11                            gender_Female    0.017657
# 12                        Contract_Two year    0.015761
# 13                          OnlineBackup_No    0.015593
# 14                      PaperlessBilling_No    0.015067
# 15                     PaperlessBilling_Yes    0.014803
# 16                               Partner_No    0.014626
# 17                              Partner_Yes    0.014358
# 18                      DeviceProtection_No    0.012837
# 19                          SeniorCitizen_0    0.012823
# 20                          SeniorCitizen_1    0.012296
# 21                            Dependents_No    0.012100
# 22                         MultipleLines_No    0.012028
# 23                        MultipleLines_Yes    0.011926
# 24    PaymentMethod_Credit card (automatic)    0.011822
# 25                           Dependents_Yes    0.011746
# 26  PaymentMethod_Bank transfer (automatic)    0.011621
# 27                         OnlineBackup_Yes    0.011078
# 28               PaymentMethod_Mailed check    0.010698
# 29                       OnlineSecurity_Yes    0.010566
# 30                        Contract_One year    0.010269
# 31                     DeviceProtection_Yes    0.010126
# 32                      InternetService_DSL    0.010037
# 33                       StreamingMovies_No    0.009593
# 34                          TechSupport_Yes    0.009574
# 35                          StreamingTV_Yes    0.009499
# 36                      StreamingMovies_Yes    0.009466
# 37                           StreamingTV_No    0.009449
# 38                     tenure_bucket_25-48m    0.008586
# 39                     tenure_bucket_13-24m    0.007867
# 40                       tenure_bucket_61m+    0.007509
# 41                      tenure_bucket_7-12m    0.007090
# 42                       charge_quantile_Q3    0.007063
# 43                       charge_quantile_Q2    0.006871
# 44                       charge_quantile_Q4    0.006099
# 45                     tenure_bucket_49-60m    0.005439
# 46          TechSupport_No internet service    0.003534
# 47         OnlineBackup_No internet service    0.003458
# 48      StreamingMovies_No internet service    0.003314
# 49                       InternetService_No    0.003012
# 50                    high_value_customer_0    0.002909
# 51       OnlineSecurity_No internet service    0.002784
# 52                       charge_quantile_Q1    0.002763
# 53                          PhoneService_No    0.002758
# 54                    high_value_customer_1    0.002699
# 55     DeviceProtection_No internet service    0.002674
# 56                         PhoneService_Yes    0.002625
# 57           MultipleLines_No phone service    0.002605
# 58          StreamingTV_No internet service    0.002382

# %%
models_info.append(
    train_eval(
        "XGBoost",
        XGBClassifier(
            n_estimators=1000,
            random_state=42,
            n_jobs=-1,
        ),
        preprocess=preprocess,
        X_train=X_train,
        X_test=X_test,
        y_train=y_train,
        y_test=y_test,
        num_cols=num_cols,
        cat_cols=cat_cols,
    )
)

# %%
models_info[2]["importance_df"]
# Out:
#                                     feature  importance
# 0                   Contract_Month-to-month    0.312433
# 1               InternetService_Fiber optic    0.216978
# 2                         OnlineSecurity_No    0.032429
# 3                         Contract_Two year    0.029008
# 4                       InternetService_DSL    0.025713
# 5                           PhoneService_No    0.020268
# 6                            TechSupport_No    0.016871
# 7                         Contract_One year    0.015967
# 8                                    tenure    0.014778
# 9                           OnlineBackup_No    0.013714
# 10    PaymentMethod_Credit card (automatic)    0.013601
# 11                       StreamingMovies_No    0.013573
# 12           PaymentMethod_Electronic check    0.013222
# 13                          SeniorCitizen_0    0.012657
# 14                       charge_quantile_Q2    0.012514
# 15                          StreamingTV_Yes    0.012318
# 16                            Dependents_No    0.011834
# 17                     tenure_bucket_13-24m    0.011552
# 18                         MultipleLines_No    0.011418
# 19                      DeviceProtection_No    0.010746
# 20                      tenure_bucket_7-12m    0.010689
# 21                      PaperlessBilling_No    0.010230
# 22                     tenure_bucket_49-60m    0.009929
# 23                           StreamingTV_No    0.009843
# 24               PaymentMethod_Mailed check    0.009538
# 25                              addon_count    0.009500
# 26  PaymentMethod_Bank transfer (automatic)    0.009418
# 27                       charge_quantile_Q3    0.009196
# 28                       charge_quantile_Q1    0.009108
# 29                        MultipleLines_Yes    0.009027
# 30                             TotalCharges    0.008683
# 31                      StreamingMovies_Yes    0.008472
# 32                               Partner_No    0.008416
# 33                           MonthlyCharges    0.008313
# 34                          TechSupport_Yes    0.008255
# 35                            gender_Female    0.008021
# 36                     DeviceProtection_Yes    0.007539
# 37                     tenure_bucket_25-48m    0.006482
# 38                         OnlineBackup_Yes    0.006436
# 39                       OnlineSecurity_Yes    0.005752
# 40                        tenure_bucket_≤6m    0.002741
# 41                       InternetService_No    0.002510
# 42                    high_value_customer_0    0.000304
# 43     DeviceProtection_No internet service    0.000000
# 44         OnlineBackup_No internet service    0.000000
# 45       OnlineSecurity_No internet service    0.000000
# 46                         PhoneService_Yes    0.000000
# 47           MultipleLines_No phone service    0.000000
# 48                              gender_Male    0.000000
# 49                              Partner_Yes    0.000000
# 50                           Dependents_Yes    0.000000
# 51                     PaperlessBilling_Yes    0.000000
# 52          TechSupport_No internet service    0.000000
# 53          StreamingTV_No internet service    0.000000
# 54      StreamingMovies_No internet service    0.000000
# 55                       tenure_bucket_61m+    0.000000
# 56                       charge_quantile_Q4    0.000000
# 57                          SeniorCitizen_1    0.000000
# 58                    high_value_customer_1    0.000000

# %% [markdown]
# # Métricas

# %%
summary_rows = []
for m in models_info:
    prec = m["report"]["weighted avg"]["precision"]
    rec = m["report"]["weighted avg"]["recall"]
    f1 = m["report"]["weighted avg"]["f1-score"]
    summary_rows.append(
        {
            "Model": m["name"],
            "AUC": round(m["auc"], 3),
            "Precision": round(prec, 3),
            "Recall": round(rec, 3),
            "F1": round(f1, 3),
        }
    )
summary_churn = pd.DataFrame(summary_rows)

# %%
summary_churn
# Out:
#           Model    AUC  Precision  Recall     F1
# 0        LogReg  0.846      0.807   0.763  0.774
# 1  RandomForest  0.819      0.784   0.796  0.786
# 2       XGBoost  0.800      0.759   0.767  0.762

# %%
# avg_monthly = churn["MonthlyCharges"].mean()
# scenarios = {"3x": 3 * avg_monthly, "6x": 6 * avg_monthly, "12x": 12 * avg_monthly}

# %%
# def cost_sim(model_info, cost_install):
#     TP = ((model_info["pred"] == 1) & (y_test == 1)).sum()
#     FP_idx = (model_info["pred"] == 1) & (y_test == 0)
#     FP = FP_idx.sum()
#     retention_cost = 0.1 * avg_monthly

#     savings = TP * cost_install - FP * retention_cost
#     return savings

# %%
# savings_rows = []
# for m in models_info:
#     for label, cost in scenarios.items():
#         savings_rows.append(
#             {
#                 "Model": m["name"],
#                 "Scenario": label,
#                 "InstallCost": round(cost, 2),
#                 "NetSavings": round(cost_sim(m, cost), 2),
#             }
#         )

# %%
# savings_churn = pd.DataFrame(savings_rows)

# %%
# savings_churn
